# %% [markdown]
# <a href="https://colab.research.google.com/github/agnesjoethomas/ML/blob/main/machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=[["p1",7,7,"bad"],["p2",7,4,"bad"],["p3",3,4,"good"],["p4",1,4,"good"]]
df=pd.DataFrame(data,columns=["P","x1","x2","Y"])
df
# Out:
#     P  x1  x2     Y
# 0  p1   7   7   bad
# 1  p2   7   4   bad
# 2  p3   3   4  good
# 3  p4   1   4  good

# %%
x=df.iloc[:,1:3]
y=df.iloc[:,-1]

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(x,y) # machine learns.. input-> indep val, dep val
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
knn.predict([[3,7]]) # input given in 2 dimension as it is a record. can be done using reshaping array
# Out:
# ['good']
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/diabetes.csv")

# %%
# to get only selected columns
df.iloc[:,[0,1,3]]
# Out:
#      Pregnancies  Glucose  SkinThickness
# 0              6      148             35
# 1              1       85             29
# 2              8      183              0
# 3              1       89             23
# 4              0      137             35
# ..           ...      ...            ...
# 763           10      101             48
# 764            2      122             27
# 765            5      121             23
# 766            1      126              0
# 767            1       93             31
#
# [768 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
x=df.iloc[:,0:8]
y=df.iloc[:,-1]

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
# random_state is given so that the training and testing datatsets dont change in each execution of the split function

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (614, 8)
# (154, 8)
# (614,)
# (154,)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
fit=knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
accuracy_score(y_test,y_pred)
# Out:
# 0.6623376623376623

# %%
classification_report(y_test,y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.75      0.71      0.73        99\n           1       0.52      0.58      0.55        55\n\n    accuracy                           0.66       154\n   macro avg       0.64      0.64      0.64       154\nweighted avg       0.67      0.66      0.67       154\n'

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[70, 29],
#        [23, 32]])

# %% [markdown]
# True Positives (TP): Correctly predicted positive instances (top-left in the default sklearn output).
#
# True Negatives (TN): Correctly predicted negative instances (bottom-right).
#
# False Positives (FP): Actual negative instances incorrectly predicted as positive (Type I error, top-right).
#
# False Negatives (FN): Actual positive instances incorrectly predicted as negative (Type II error, bottom-left).

# %%
df=pd.read_csv("/content/Housing.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
for i in ["mainroad","guestroom","basement","hotwaterheating","airconditioning","prefarea"]:
  df[i] = df[i].replace({'yes': 1, 'no': 0})
df["furnishingstatus"] = df["furnishingstatus"].replace({'furnished': 2, 'semi-furnished': 1, "unfurnished": 0})

df
# Out:
# /tmp/ipython-input-2286113308.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["furnishingstatus"] = df["furnishingstatus"].replace({'furnished': 2, 'semi-furnished': 1, "unfurnished": 0})
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# ...

# %%
x=df.iloc[:,1:]
y=df.iloc[:,0]
print(y)
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
#   File "/tmp/ipython-input-1969619255.py", line 1
#     accuracy score(y_test,y_pred)
#              ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Iris.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
df["Species"] = df["Species"].replace({'Iris-setosa': 2, 'Iris-versicolor': 1, "Iris-virginica": 0})
# Out:
# /tmp/ipython-input-1198179358.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Species"] = df["Species"].replace({'Iris-setosa': 2, 'Iris-versicolor': 1, "Iris-virginica": 0})

# %%
x=df.iloc[:,0:5]
y=df.iloc[:,-1]
print(y)
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
#       ..
# 145    0
# 146    0
# 147    0
# 148    0
# 149    0
# Name: Species, Length: 150, dtype: int64

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=43,test_size=0.4)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9833333333333333

# %%
df=pd.read_csv("/content/tested.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.drop(columns=['PassengerId','Name','Ticket','Fare','Embarked','Cabin'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  418 non-null    int64
#  1   Pclass    418 non-null    int64
#  2   Sex       418 non-null    object
#  3   Age       332 non-null    float64
#  4   SibSp     418 non-null    int64
#  5   Parch     418 non-null    int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 19.7+ KB

# %%
import numpy as np

# %%
df["Age"].fillna(np.mean(df["Age"]),inplace=True)
# Out:
# /tmp/ipython-input-3768911314.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(np.mean(df["Age"]),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  418 non-null    int64
#  1   Pclass    418 non-null    int64
#  2   Sex       418 non-null    object
#  3   Age       418 non-null    float64
#  4   SibSp     418 non-null    int64
#  5   Parch     418 non-null    int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 19.7+ KB

# %%
df["Sex"]=df["Sex"].replace({"male":1,"female":2})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  418 non-null    int64
#  1   Pclass    418 non-null    int64
#  2   Sex       418 non-null    int64
#  3   Age       418 non-null    float64
#  4   SibSp     418 non-null    int64
#  5   Parch     418 non-null    int64
# dtypes: float64(1), int64(5)
# memory usage: 19.7 KB
# /tmp/ipython-input-1507514219.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Sex"]=df["Sex"].replace({"male":1,"female":2})

# %%
x=df.iloc[:,1:]
y=df.iloc[:,1]

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
yp=knn.predict(x_test)
accuracy_score(y_test,yp)
# Out:
# 0.8214285714285714

# %% [markdown]
# ##**Using standard scaler**

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

# %%
df=pd.read_csv("/content/diabetes (1).csv")
from sklearn.preprocessing import StandardScaler

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
x=df.iloc[:,0:8]
y=df.iloc[:,-1]

# %%
sc=StandardScaler()
sc.fit(x)
# Out:
# StandardScaler()

# %%
x=sc.transform(x)
print(x)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
yp=knn.predict(x_test)
from sklearn.metrics import accuracy_score,ConfusionMatrixDisplay
accuracy_score(y_test,yp)

print(ConfusionMatrixDisplay.from_predictions(y_test,yp))

# %%
new=sc.transform([[6,148,72,35,0,33.6,0.627,50]])# fit_transform or fit not used for scaling new datapoints as already sc model is fit
knn.predict(new)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([1])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,yp))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.80      0.77        99
#            1       0.57      0.49      0.53        55
#
#     accuracy                           0.69       154
#    macro avg       0.66      0.64      0.65       154
# weighted avg       0.68      0.69      0.68       154

# %% [markdown]
# #SVM
